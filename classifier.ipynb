# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn

# %%
df = pd.read_csv('bank-additional-full.csv', sep=";")
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
y = df.iloc[0:, 20] #this is the output variable dataframe
X = df.iloc[0:, 0:20] #this is the rest of the factors except the output variable

# %%
'''STEP 2'''
from sklearn.model_selection import train_test_split

#we use train_test_split to randomly generate sets and we also split the output value already
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=(2021-10-25)) # 20% test, 80% train

# %%
'''STEP 3'''
#drop the 'duration' column from both train and test since it will affect the output highly
X_train = X_train.drop(columns=['duration'])
X_test = X_test.drop(columns=['duration'])

#X_train

# %%
'''STEP 4 -> turn categorical variables between 1-10 into dummy variables'''
#categorical vars in a list 
listOfCats = ['job','marital','education','default','housing','loan','contact','month','day_of_week']
X_train = pd.get_dummies(data=X_train, columns=['job','marital','education','default','housing','loan','contact','month','day_of_week'])
X_test = pd.get_dummies(data=X_test, columns=['job','marital','education','default','housing','loan','contact','month','day_of_week'])

X_train
# Out:
#        age  campaign  pdays  previous     poutcome  emp.var.rate  \
# 10155   49         2    999         0  nonexistent           1.4
# 11854   38         5    999         0  nonexistent           1.4
# 23243   59        10    999         0  nonexistent           1.4
# 20384   38         1    999         0  nonexistent           1.4
# 28110   47         2    999         0  nonexistent          -1.8
# ...    ...       ...    ...       ...          ...           ...
# 17987   31        13    999         0  nonexistent           1.4
# 20299   29         5    999         0  nonexistent           1.4
# 14556   49         1    999         0  nonexistent           1.4
# 28981   47         1    999         0  nonexistent          -1.8
# 32764   35         5    999         0  nonexistent          -1.8
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed  ...  month_mar  \
# 10155          94.465          -41.8      4.958       5228.1  ...          0
# ...

# %%
'''STEP 5: running the data on a categorical naive bayes classifier'''
from sklearn.naive_bayes import CategoricalNB

cnb = CategoricalNB()
cnb.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-a447eb7e5050> in <module>
#       3
#       4 cnb = CategoricalNB()
# ----> 5 cnb.fit(X_train, y_train)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#    1164         self : object
#    1165         """
# -> 1166         return super().fit(X, y, sample_weight=sample_weight)
#    1167
#    1168     def partial_fit(self, X, y, classes=None, sample_weight=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     610         self : object
#     611         """
# --> 612         X, y = self._check_X_y(X, y)
#     613         _, n_features = X.shape
#     614         self.n_features_ = n_features
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/naive_bayes.py in _check_X_y(self, X, y)
# ...
